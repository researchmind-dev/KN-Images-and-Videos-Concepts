# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../images/giraffe-Kenya.png") # Replace 'sample.jpg' with your image path

# %%
image_grey = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

equalised_image = cv2.equalizeHist(image_grey) # all histogram equilization technique work on greyscale , not RGB
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(4,4))

clahe_equalised_image = clahe.apply(image_grey)

plt.figure(figsize=(12,8))

plt.subplot(1,3,1)
plt.imshow(image_grey, cmap='grey')
plt.title("Original image")

plt.subplot(1,3,2)
plt.imshow(equalised_image, cmap='grey')
plt.title("Equalised image")

plt.subplot(1,3,3)
plt.imshow(clahe_equalised_image, cmap='grey')
plt.title("Clahe equalised image")

plt.show()

# %%
yuv_image = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)

yuv_image[:,:,0] = clahe.apply(yuv_image[:,:,0])

yuv_image_BGR = cv2.cvtColor(yuv_image, cv2.COLOR_YUV2BGR)

yuv_image_rgb = cv2.cvtColor(yuv_image_BGR, cv2.COLOR_BGR2RGB)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12,8))

plt.subplot(1,2,1)
plt.imshow(image_rgb)
plt.title("Original rgb image")

plt.subplot(1,2,2)
plt.imshow(yuv_image_rgb)
plt.title("Clahe Equalised rgb image")

plt.show()

# %%
# like see how look like old image convert to new type image and more features details with equilizations
